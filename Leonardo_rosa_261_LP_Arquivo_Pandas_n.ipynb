# %% [markdown]
# ###1. Crie um DataFrame (df) a partir de um dicionário de aluno, neste terá as chaves nome, disciplina, média. Insira pelo menos 4 valores para cada chave (use vetor). Apresente ao final a df.

# %%
# Digite seu código aqui
# Esta execução abaixo é exemplo, mas não é exatamento o que deve implementar

import pandas as pd

alunos = {
    'Nome': ['Ana', 'Bruno', 'Carlos', 'Diana'],
    'Disciplina': ['Matemática', 'História', 'Física', 'Biologia'],
    'Media': [8.5, 7.0, 9.0, 6.5]
}

df = pd.DataFrame(alunos)
print(df)
# Out:
#      Nome  Disciplina  Media
# 0     Ana  Matemática    8.5
# 1   Bruno    História    7.0
# 2  Carlos      Física    9.0
# 3   Diana    Biologia    6.5

# %% [markdown]
# ###2. Ler o arquivo Vendas.xlsx. Apresente o resultado da função/ método info() e describe() para explorar os dados.

# %%
import pandas as pd

df = pd.read_excel('Vendas.xlsx')

df.info()
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7089 entries, 0 to 7088
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Código Venda    7089 non-null   int64
#  1   Data            7089 non-null   datetime64[ns]
#  2   ID Loja         7089 non-null   object
#  3   Produto         7089 non-null   object
#  4   Quantidade      7089 non-null   int64
#  5   Valor Unitário  7089 non-null   int64
#  6   Valor Final     7089 non-null   int64
# dtypes: datetime64[ns](1), int64(4), object(2)
# memory usage: 387.8+ KB
#        Código Venda                           Data   Quantidade  \
# count   7089.000000                           7089  7089.000000
# mean   67492.398928  2023-12-13 01:45:49.894202112     2.147976
# min    65014.000000            2023-12-01 00:00:00     1.000000
# 25%    66211.000000            2023-12-07 00:00:00     1.000000
# ...

# %% [markdown]
# ###3. Ler o arquivo Vendas.xlsx. Apresente o resultado da função/ método describe(include='object'), apenas da coluna/campo 'Produto'

# %%
import pandas as pd

df = pd.read_excel('Vendas.xlsx')


print(df['Produto'].describe(include='object'))
# Out:
# count             7089
# unique             121
# top       Camisa Linho
# freq                77
# Name: Produto, dtype: object

# %% [markdown]
# ###4. Ler o arquivo Vendas.xlsx. Apresente o conteúdo da linha 13 até 21.

# %%
import pandas as pd

df = pd.read_excel('Vendas.xlsx')
print(df.iloc[13:22])
# Out:
#     Código Venda       Data           ID Loja         Produto  Quantidade  \
# 13         68101 2023-12-16  Shopping América  Bermuda Xadrez           1
# 14         68817 2023-12-20  Shopping América  Bermuda Xadrez           2
# 15         69622 2023-12-24  Shopping América  Bermuda Xadrez           2
# 16         65036 2023-12-01  Shopping América           Calça           1
# 17         65136 2023-12-01  Shopping América           Calça           3
# 18         65553 2023-12-03  Shopping América           Calça           2
# 19         67787 2023-12-15  Shopping América           Calça           2
# 20         68646 2023-12-19  Shopping América     Calça Linho           3
# 21         68713 2023-12-19  Shopping América     Calça Linho           2
#
#     Valor Unitário  Valor Final
# 13             155          155
# 14             155          310
# 15             155          310
# 16             170          170
# 17             170          510
# ...

# %% [markdown]
# ###5. Ler o arquivo Vendas.xlsx. Apresente o conteúdo da coluna/campo 'Produto'

# %%
import pandas as pd

df = pd.read_excel('Vendas.xlsx')
print(df['Produto'])
# Out:
# 0                Bermuda
# 1                Bermuda
# 2        Bermuda Estampa
# 3        Bermuda Estampa
# 4        Bermuda Estampa
#               ...
# 7084    Vestido Listrado
# 7085    Vestido Listrado
# 7086    Vestido Listrado
# 7087      Vestido Xadrez
# 7088      Vestido Xadrez
# Name: Produto, Length: 7089, dtype: object

# %% [markdown]
# 6. Ler o arquivo Vendas.xlsx. Apresente os produto começando com a letra “V”.

# %%
import pandas as pd

df = pd.read_excel('Vendas.xlsx')
filtro = df['Produto'].str.startswith('V')
resultado = df[filtro]
print(resultado)
# Out:
#      Nome
# 0     Ana
# 2   Alice
# 4  Amanda

# %% [markdown]
# ###7. Ler o arquivo Vendas.xlsx. Apresente os produtos com quantidade maiores que 2.

# %%
import pandas as pd

df = pd.read_excel('Vendas.xlsx')
filtro = (df['Quantidade'] > 2)
print(df['Produto'][filtro])
# Out:
# 2        Bermuda Estampa
# 8       Bermuda Listrado
# 9         Bermuda Xadrez
# 11        Bermuda Xadrez
# 17                 Calça
#               ...
# 7072             Vestido
# 7073             Vestido
# 7077     Vestido Estampa
# 7081        Vestido Liso
# 7086    Vestido Listrado
# Name: Produto, Length: 2253, dtype: object

# %% [markdown]
# ###8. Ler o arquivo Vendas.xlsx. Apresente os valores finais são maiores que R$ 400,00.

# %%
import pandas as pd

df = pd.read_excel('Vendas.xlsx')
filtro = (df['Valor Final'] > 400)
print(df['Valor Final'][filtro])
# Out:
# 2        676
# 8        815
# 9        465
# 11       620
# 17       510
#         ...
# 7084    1418
# 7085    1418
# 7086    2127
# 7087     709
# 7088     709
# Name: Valor Final, Length: 2335, dtype: int64

# %% [markdown]
# ###9. Ler o arquivo Vendas.xlsx. Apresente os valores finais entre R$ 1.000,00 e R\$ 2.000,00.

# %%
import pandas as pd

df = pd.read_excel('Vendas.xlsx')
filtro = (df['Valor Final'] > 1000) & (df['Valor Final'] < 2000)
print(df[filtro])
# Out:
#       Código Venda       Data           ID Loja           Produto  Quantidade  \
# 88           65106 2023-12-01  Shopping América    Casaco Estampa           4
# 134          68914 2023-12-20  Shopping América        Cinto Liso           5
# 142          69616 2023-12-24  Shopping América      Cinto Xadrez           5
# 201          68105 2023-12-16  Shopping América           Mochila           4
# 207          65328 2023-12-02  Shopping América     Mochila Linho           4
# ...            ...        ...               ...               ...         ...
# 7040         69750 2023-12-24    Shopping Terra       Sapato Liso           3
# 7076         67288 2023-12-12    Shopping Terra   Vestido Estampa           2
# 7080         68759 2023-12-19    Shopping Terra     Vestido Linho           2
# 7084         65570 2023-12-03    Shopping Terra  Vestido Listrado           2
# 7085         66370 2023-12-08    Shopping Terra  Vestido Listrado           2
#
# ...

# %% [markdown]
# 888888888888888888888888888888888888888888888888888888888888

# %%
import matplotlib.pyplot as plt
rotulos = ['Diretor', 'Desenvolvedor', 'Gerente de TI','Gerente BD']
tamanho = [12, 54, 19,32]
cores = ['red', 'pink', 'cyan','yellow']
fig, pizza = plt.subplots()
pizza.pie(tamanho, labels=rotulos, colors=cores, autopct="%1.1f%%")
pizza.set_title('Cargos')
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_excel('/content/drive/MyDrive/Vendas.xlsx')
#print(df)
#display(df)
#print(df['ID Loja'].value_counts())
#print(df['ID Loja'].value_counts(normalize=True))#porcentagem
#print(df['Produto'].value_counts())
#faturamento = df['Valor Final'].sum()
#print(f'Faturamento obtido R$ {faturamento:,.2f}')
#print(df.sample())
#print(df.sample(10))
#print('Quantidade de lojas=', sum(df['ID Loja'] == 'Shopping América') )

#seleção apenas dos Shopping Lua
tem_shopping_lua = df['ID Loja'] == 'Shopping Lua'
#a variável shopping_lua recebe todas as colunas dos dados apenas deste shopping

shopping_lua = df[tem_shopping_lua]
print(f'Média de preços do Shopping Lua=',shopping_lua['Valor Final'].mean())
print(f'Faturamente total do Shopping Lua=',shopping_lua['Valor Final'].sum())
print(f'Quantidade de Shopping Lua=',shopping_lua['ID Loja'].count())

import matplotlib.pyplot as plt
plt.hist(shopping_lua['Valor Unitário'], 10, rwidth=0.8, color = 'red')
plt.title('Vendas realizadas pelo Shopping Lua')
plt.xlabel('Preço dos produtos')
plt.ylabel('Quantidade de produtos')
plt.show()
# Out:
# Média de preços do Shopping Lua= 400.5503875968992
# Faturamente total do Shopping Lua= 103342
# Quantidade de Shopping Lua= 258

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Propaganda.csv')
#print(df)

import plotly.express as px
fig = px.histogram(df, x="TV")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Propaganda.csv')

import plotly.express as px
#fig = px.bar(df, title="Vendas por Mês")
#ou
#fig = px.bar(df, x='TV',title="Vendas por Mês")
fig = px.scatter(df, y = 'TV')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 10. Crie um programa que carregue o arquivo Vendas.xlsx, por meio da biblioteca Pandas. Calcule e apresente a média da coluna do arquivo 'Valor Unitário'.

# %%
# Digite seu código aqui
# .mean()

import pandas as pd

df = pd.read_excel('Vendas.xlsx')
print(f'Média do Valor Unitário =',df['Valor Unitário'].mean())
# Out:
# Média do Valor Unitário = 193.6511496685005

# %% [markdown]
# ### 11. Crie um programa que carregue o arquivo Vendas.xlsx, por meio da biblioteca Pandas. Calcule e apresente a quantidade mínima da coluna do arquivo 'Quantidade'.

# %%
# Digite seu código aqui
# .min()

import pandas as pd

df = pd.read_excel('Vendas.xlsx')
print(f'Quantidade mínima =',df['Quantidade'].min())
# Out:
# Quantidade mínima = 1

# %% [markdown]
# ### 12. Crie um programa que carregue o arquivo Vendas.xlsx, por meio da biblioteca Pandas. Calcule e apresente o valor máximo da coluna do arquivo 'Valor Final'.

# %%
# Digite seu código aqui
# .max()

import pandas as pd

df = pd.read_excel('Vendas.xlsx')
print(f'Quantidade máxima =',df['Quantidade'].max())

# %% [markdown]
# ### 13. Crie um programa que carregue o arquivo Propaganda.csv, por meio da biblioteca Pandas. Calcule e apresente o valor máximo da coluna do arquivo 'Jornal'.

# %%
# Digite seu código aqui

import pandas as pd

df = pd.read_csv('Propaganda.csv')
print(f'Quantidade máxima =',df['Jornal'].max())
# Out:
# Quantidade máxima = 114.0

# %% [markdown]
# ### 14. Crie um programa que carregue o arquivo Propaganda.csv, por meio da biblioteca Pandas. Gere um histograma, referente a coluna Rádio, utilizando a biblioteca plotly.

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv('Propaganda.csv')
fig = px.histogram(df, x="Radio")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 15. Crie um programa que carregue o arquivo Propaganda.csv, por meio da biblioteca Pandas. Gere um histograma, referente a coluna TV, utilizando a biblioteca Matplotlib, apresente na cor blueviolet.

# %%
import matplotlib.pyplot as plt
df = pd.read_csv('Propaganda.csv')
plt.hist(df['TV'], 5, rwidth=0.8, color = 'blueviolet')
# Out:
# (array([41., 39., 36., 48., 36.]),
#  array([  0.7 ,  59.84, 118.98, 178.12, 237.26, 296.4 ]),
#  <BarContainer object of 5 artists>)
